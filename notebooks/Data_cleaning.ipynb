# %%
import numpy as np
import pandas as pd

# %%
Data_Table = pd.read_csv('../Data/Data.csv' , header = None)

Data_Table.head()
# Out:
#          0          1            2             3               4          5   \
# 0        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 1    842302          M        17.99         10.38           122.8       1001
# 2    842517          M        20.57         17.77           132.9       1326
# 3  84300903          M        19.69         21.25             130       1203
# 4  84348301          M        11.42         20.38           77.58      386.1
#
#                 6                 7               8                    9   \
# 0  smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 1           0.1184            0.2776          0.3001               0.1471
# 2          0.08474           0.07864          0.0869              0.07017
# 3           0.1096            0.1599          0.1974               0.1279
# 4           0.1425            0.2839          0.2414               0.1052
#
# ...

# %%
New_columns = Data_Table.loc[ 0 , :].values

New_columns
# Out:
# array(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean',
#        'concavity_mean', 'concave points_mean', 'symmetry_mean',
#        'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se',
#        'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', np.float64(nan)],
#       dtype=object)

# %%
Data_Table.columns = New_columns

Data_Table = Data_Table.drop(0)

Data_Table.reset_index(drop = True , inplace=True)

Data_Table_df = pd.DataFrame(Data_Table)

# %%
Data_Table_df
# Out:
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0      842302         M       17.99        10.38          122.8      1001
# 1      842517         M       20.57        17.77          132.9      1326
# 2    84300903         M       19.69        21.25            130      1203
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34          135.1      1297
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39            142      1479
# 565    926682         M       20.13        28.25          131.2      1261
# 566    926954         M        16.6        28.08          108.3     858.1
# 567    927241         M        20.6        29.33          140.1      1265
# 568     92751         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# ...

# %%
print(f'Shape : {Data_Table_df.shape}')
print("\nMissing Values:")
print(Data_Table.isnull().sum().sum())
# Out:
# Shape : (569, 33)
#
# Missing Values:
# 569

# %%
Data_Table_df
# Out:
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0      842302         M       17.99        10.38          122.8      1001
# 1      842517         M       20.57        17.77          132.9      1326
# 2    84300903         M       19.69        21.25            130      1203
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34          135.1      1297
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39            142      1479
# 565    926682         M       20.13        28.25          131.2      1261
# 566    926954         M        16.6        28.08          108.3     858.1
# 567    927241         M        20.6        29.33          140.1      1265
# 568     92751         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# ...

# %%
print(f'Shape : {Data_Table_df.shape}')
print("\nMissing Values:")
print(Data_Table_df.isnull().sum().sum())
# Out:
# Shape : (569, 33)
#
# Missing Values:
# 569

# %%
Data_Table_df.drop( columns= [Data_Table_df.columns[-1]] , inplace=True)

# %%
Data_Table_df
# Out:
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0      842302         M       17.99        10.38          122.8      1001
# 1      842517         M       20.57        17.77          132.9      1326
# 2    84300903         M       19.69        21.25            130      1203
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34          135.1      1297
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39            142      1479
# 565    926682         M       20.13        28.25          131.2      1261
# 566    926954         M        16.6        28.08          108.3     858.1
# 567    927241         M        20.6        29.33          140.1      1265
# 568     92751         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# ...

# %%
print(f'Shape : {Data_Table_df.shape}')
print("\nMissing Values:")
print(Data_Table_df.isnull().sum().sum())
# Out:
# Shape : (569, 32)
#
# Missing Values:
# 0

# %%
Data_Table_df
# Out:
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0      842302         M       17.99        10.38          122.8      1001
# 1      842517         M       20.57        17.77          132.9      1326
# 2    84300903         M       19.69        21.25            130      1203
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34          135.1      1297
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39            142      1479
# 565    926682         M       20.13        28.25          131.2      1261
# 566    926954         M        16.6        28.08          108.3     858.1
# 567    927241         M        20.6        29.33          140.1      1265
# 568     92751         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# ...

# %%
Data_Table_df.drop(columns = ['id'] , inplace = True)

# %%
Data_Table_df
# Out:
#     diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0           M       17.99        10.38          122.8      1001
# 1           M       20.57        17.77          132.9      1326
# 2           M       19.69        21.25            130      1203
# 3           M       11.42        20.38          77.58     386.1
# 4           M       20.29        14.34          135.1      1297
# ..        ...         ...          ...            ...       ...
# 564         M       21.56        22.39            142      1479
# 565         M       20.13        28.25          131.2      1261
# 566         M        16.6        28.08          108.3     858.1
# 567         M        20.6        29.33          140.1      1265
# 568         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  \
# 0            0.1184           0.2776         0.3001              0.1471
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

Data_Table_df['diagnosis'] = Data_Table_df['diagnosis'].map({'M':1 , 'B':0})

Data_Table_df
# Out:
#      diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0            1       17.99        10.38          122.8      1001
# 1            1       20.57        17.77          132.9      1326
# 2            1       19.69        21.25            130      1203
# 3            1       11.42        20.38          77.58     386.1
# 4            1       20.29        14.34          135.1      1297
# ..         ...         ...          ...            ...       ...
# 564          1       21.56        22.39            142      1479
# 565          1       20.13        28.25          131.2      1261
# 566          1        16.6        28.08          108.3     858.1
# 567          1        20.6        29.33          140.1      1265
# 568          0        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  \
# 0            0.1184           0.2776         0.3001              0.1471
# ...

# %%
plt.figure(figsize = (12,8))
sns.heatmap(Data_Table_df.corr() )

plt.show()
